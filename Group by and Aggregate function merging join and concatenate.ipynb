# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Admin\Downloads\Flavors.csv")

# %%
df
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
df.describe()
# Out:
#        Flavor Rating  Texture Rating  Total Rating
# count         9.0000        9.000000      9.000000
# mean          6.6000        6.177778     12.800000
# std           2.5387        1.478832      4.030509
# min           2.3000        3.400000      5.700000
# 25%           4.7000        5.000000      9.700000
# 50%           6.9000        6.500000     13.400000
# 75%           8.2000        7.100000     15.300000
# max          10.0000        8.000000     18.000000

# %%
group = df.groupby('Base Flavor')

# %%
group.mean()
# Out:
#              Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate              8.4        7.233333         15.70
# Vanilla                5.7        5.650000         11.35

# %%
df.groupby('Base Flavor').mean()
# Out:
#              Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate              8.4        7.233333         15.70
# Vanilla                5.7        5.650000         11.35

# %%
df.groupby('Base Flavor').count()
# Out:
#              Flavor  Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate         3      3              3               3             3
# Vanilla           6      6              6               6             6

# %%
df.groupby('Base Flavor').min()
# Out:
#                   Flavor Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate      Chocolate   Yes            8.2             7.0          15.2
# Vanilla      Cake Batter    No            2.3             3.4           5.7

# %%
df.groupby('Base Flavor').max()
# Out:
#                  Flavor Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate    Rocky Road   Yes            8.8             7.6          16.6
# Vanilla         Vanilla   Yes           10.0             8.0          18.0

# %%
emp_records ={
    'id': [1, 2, 3, 4, 5],
     'name' : ['ram', 'sham', 'aam', 'naam', 'raj'],
     'Mobile': ['moto', 'nokia', 'samsung', 'lg', 'oneplus']
    }

# %%
df1 = pd.DataFrame(emp_records)

# %%
df1
# Out:
#    id  name   Mobile new-col
# 0   1   ram     moto  Python
# 1   2  sham    nokia  Python
# 2   3   aam  samsung  Python
# 3   4  naam       lg  Python
# 4   5   raj  oneplus  Python

# %%
df1.loc[1,'new-col'] = 'Java'

# %%
df1
# Out:
#    id  name   Mobile new-col
# 0   1   ram     moto  Python
# 1   2  sham    nokia    Java
# 2   3   aam  samsung  Python
# 3   4  naam       lg  Python
# 4   5   raj  oneplus  Python

# %%
df1.drop('id', axis=1)
# Out:
#    name   Mobile new-col
# 0   ram     moto  Python
# 1  sham    nokia    Java
# 2   aam  samsung  Python
# 3  naam       lg  Python
# 4   raj  oneplus  Python

# %%
df1
# Out:
#    id  name   Mobile new-col
# 0   1   ram     moto  Python
# 1   2  sham    nokia    Java
# 2   3   aam  samsung  Python
# 3   4  naam       lg  Python
# 4   5   raj  oneplus  Python
