# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Admin\city_temperature.csv")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_21540\2625927041.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\Admin\city_temperature.csv")

# %%
df
# Out:
#                 Region  Country                   State                  City  \
# 0               Africa  Algeria                     NaN               Algiers
# 1               Africa  Algeria                     NaN               Algiers
# 2               Africa  Algeria                     NaN               Algiers
# 3               Africa  Algeria                     NaN               Algiers
# 4               Africa  Algeria                     NaN               Algiers
# ...                ...      ...                     ...                   ...
# 2906322  North America       US  Additional Territories  San Juan Puerto Rico
# 2906323  North America       US  Additional Territories  San Juan Puerto Rico
# 2906324  North America       US  Additional Territories  San Juan Puerto Rico
# 2906325  North America       US  Additional Territories  San Juan Puerto Rico
# 2906326  North America       US  Additional Territories  San Juan Puerto Rico
#
# ...

# %%
df['AvgTemperature'].max()
# Out:
# 110.0

# %%
df['AvgTemperature'].min()
# Out:
# -99.0

# %%
df[df['AvgTemperature']==df['AvgTemperature'].max()][['Region', 'City']]
# Out:
#               Region    City
# 1034962  Middle East  Kuwait

# %%
df[df['AvgTemperature']==df['AvgTemperature'].min()][['Year', 'City', 'AvgTemperature']]
# Out:
#          Year                  City  AvgTemperature
# 220      1995               Algiers           -99.0
# 221      1995               Algiers           -99.0
# 408      1996               Algiers           -99.0
# 409      1996               Algiers           -99.0
# 1453     1998               Algiers           -99.0
# ...       ...                   ...             ...
# 2905471  2011  San Juan Puerto Rico           -99.0
# 2905534  2011  San Juan Puerto Rico           -99.0
# 2905689  2011  San Juan Puerto Rico           -99.0
# 2905726  2011  San Juan Puerto Rico           -99.0
# 2905749  2012  San Juan Puerto Rico           -99.0
#
# [79672 rows x 3 columns]

# %%
df[df['AvgTemperature']==df['AvgTemperature'].min()][['Country', 'City','Year']]
# Out:
#          Country                  City  Year
# 220      Algeria               Algiers  1995
# 221      Algeria               Algiers  1995
# 408      Algeria               Algiers  1996
# 409      Algeria               Algiers  1996
# 1453     Algeria               Algiers  1998
# ...          ...                   ...   ...
# 2905471       US  San Juan Puerto Rico  2011
# 2905534       US  San Juan Puerto Rico  2011
# 2905689       US  San Juan Puerto Rico  2011
# 2905726       US  San Juan Puerto Rico  2011
# 2905749       US  San Juan Puerto Rico  2012
#
# [79672 rows x 3 columns]

# %%
df[df['Year']==df[df['AvgTemperature']==df['AvgTemperature'].min()]['Year'].min()]
# Out:
#         Region  Country State     City  Month  Day  Year  AvgTemperature
# 743367  Europe  Germany   NaN  Hamburg     12    3   200           -99.0
# 743368  Europe  Germany   NaN  Hamburg     12    4   200           -99.0
# 743369  Europe  Germany   NaN  Hamburg     12    5   200           -99.0
# 743370  Europe  Germany   NaN  Hamburg     12    6   200           -99.0
# 743371  Europe  Germany   NaN  Hamburg     12    7   200           -99.0
# ...        ...      ...   ...      ...    ...  ...   ...             ...
# 845935  Europe   Norway   NaN     Oslo     12   27   200           -99.0
# 845936  Europe   Norway   NaN     Oslo     12   28   200           -99.0
# 845937  Europe   Norway   NaN     Oslo     12   29   200           -99.0
# 845938  Europe   Norway   NaN     Oslo     12   30   200           -99.0
# 845939  Europe   Norway   NaN     Oslo     12   31   200           -99.0
#
# [89 rows x 8 columns]

# %%
df['Year'] = df['Year'].apply(lambda x : str(2000) if x==str(200) else str(x))

# %%
df['Year'].min()
# Out:
# '1995'

# %%
df['Year'].unique()
# Out:
# array(['1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020', '201', '200'], dtype=object)

# %%
df1 = pd.read_csv(r"C:\Users\Admin\Bengaluru_House_Data.csv")

# %%
df1
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %% [markdown]
# # df1[df['price']== df1['price'].max()][['size','location', 'total_sqft']]

# %%
df1[df1['price']== df1['price'].max()][['size','location', 'total_sqft', 'price']]
# Out:
#              size        location total_sqft   price
# 13067  10 Bedroom  Defence Colony       7150  3600.0

# %%
df1['size'].dropna(inplace=True)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21540\4047458266.py in <module>
# ----> 1 df1['size']= df1['size'].apply(lambda x : x.split(' ')[0])
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1086             return self.apply_str()
#    1087
# -> 1088         return self.apply_standard()
#    1089
#    1090     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1141                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1142                 # "Callable[[Any], Any]"
# ...

# %%
df1['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', nan, '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
df1.dropna(inplace=True)

# %%
df1['size']= df1['size'].apply(lambda x : x.split(' ')[0])

# %%
df1
# Out:
#                   area_type   availability                  location size  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II    2
# 1                Plot  Area  Ready To Move          Chikka Tirupathi    4
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli    3
# 5      Super built-up  Area  Ready To Move                Whitefield    2
# 11               Plot  Area  Ready To Move                Whitefield    4
# ...                     ...            ...                       ...  ...
# 13313  Super built-up  Area  Ready To Move               Uttarahalli    3
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout    3
# 13315        Built-up  Area  Ready To Move                Whitefield    5
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar    2
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar    4
#
#        society total_sqft  bath  balcony   price
# ...
